# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("D:/Source file/lr_dataset.csv")

# %%
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252        41  6.984127   1.023810         322  2.555556     37.88
# 1      8.3014        21  6.238137   0.971880        2401  2.109842     37.86
# 2      7.2574        52  8.288136   1.073446         496  2.802260     37.85
# 3      5.6431        52  5.817352   1.073059         558  2.547945     37.85
# 4      3.8462        52  6.281853   1.081081         565  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603        25  5.045455   1.133333         845  2.560606     39.48
# 20636  2.5568        18  6.114035   1.315789         356  3.122807     39.49
# 20637  1.7000        17  5.205543   1.120092        1007  2.325635     39.43
# 20638  1.8672        18  5.329513   1.171920         741  2.123209     39.43
# 20639  2.3886        16  5.254717   1.162264        1387  2.616981     39.37
#
#        Longitude  House_price
# ...

# %%
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252        41  6.984127   1.023810         322  2.555556     37.88
# 1  8.3014        21  6.238137   0.971880        2401  2.109842     37.86
# 2  7.2574        52  8.288136   1.073446         496  2.802260     37.85
# 3  5.6431        52  5.817352   1.073059         558  2.547945     37.85
# 4  3.8462        52  6.281853   1.081081         565  2.181467     37.85
#
#    Longitude  House_price
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %%
df.tail()
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 20635  1.5603        25  5.045455   1.133333         845  2.560606     39.48
# 20636  2.5568        18  6.114035   1.315789         356  3.122807     39.49
# 20637  1.7000        17  5.205543   1.120092        1007  2.325635     39.43
# 20638  1.8672        18  5.329513   1.171920         741  2.123209     39.43
# 20639  2.3886        16  5.254717   1.162264        1387  2.616981     39.37
#
#        Longitude  House_price
# 20635    -121.09        0.781
# 20636    -121.21        0.771
# 20637    -121.22        0.923
# 20638    -121.32        0.847
# 20639    -121.24        0.894

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MedInc       20640 non-null  float64
#  1   HouseAge     20640 non-null  int64
#  2   AveRooms     20640 non-null  float64
#  3   AveBedrms    20640 non-null  float64
#  4   Population   20640 non-null  int64
#  5   AveOccup     20640 non-null  float64
#  6   Latitude     20640 non-null  float64
#  7   Longitude    20640 non-null  float64
#  8   House_price  20640 non-null  float64
# dtypes: float64(7), int64(2)
# memory usage: 1.4 MB

# %%
df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude   House_price
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# ...

# %%
df.isnull().sum()
# Out:
# MedInc         0
# HouseAge       0
# AveRooms       0
# AveBedrms      0
# Population     0
# AveOccup       0
# Latitude       0
# Longitude      0
# House_price    0
# dtype: int64

# %%
df.shape
# Out:
# (20640, 9)

# %%
import seaborn as sea

# %%
df.columns
# Out:
# Index(['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup',
#        'Latitude', 'Longitude', 'House_price'],
#       dtype='object')

# %%
df_cols=df[['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup',
       'Latitude', 'Longitude', 'House_price']]

# %%
i=df_cols['MedInc'].quantile(0.75)
i
# Out:
# np.float64(4.74325)

# %%
Q1=df_cols.quantile(0.25)
Q1
# Out:
# MedInc           2.563400
# HouseAge        18.000000
# AveRooms         4.440716
# AveBedrms        1.006079
# Population     787.000000
# AveOccup         2.429741
# Latitude        33.930000
# Longitude     -121.800000
# House_price      1.196000
# Name: 0.25, dtype: float64

# %%
Q3=df_cols.quantile(0.75)
Q3
# Out:
# MedInc            4.743250
# HouseAge         37.000000
# AveRooms          6.052381
# AveBedrms         1.099526
# Population     1725.000000
# AveOccup          3.282261
# Latitude         37.710000
# Longitude      -118.010000
# House_price       2.647250
# Name: 0.75, dtype: float64

# %%
iqr=Q3-Q1
iqr
# Out:
# MedInc           2.179850
# HouseAge        19.000000
# AveRooms         1.611665
# AveBedrms        0.093447
# Population     938.000000
# AveOccup         0.852520
# Latitude         3.780000
# Longitude        3.790000
# House_price      1.451250
# dtype: float64

# %%
lower=Q1-1.5*iqr
lower
# Out:
# MedInc          -0.706375
# HouseAge       -10.500000
# AveRooms         2.023219
# AveBedrms        0.865909
# Population    -620.000000
# AveOccup         1.150961
# Latitude        28.260000
# Longitude     -127.485000
# House_price     -0.980875
# dtype: float64

# %%
upper=Q3+1.5*iqr
upper
# Out:
# MedInc            8.013025
# HouseAge         65.500000
# AveRooms          8.469878
# AveBedrms         1.239697
# Population     3132.000000
# AveOccup          4.561041
# Latitude         43.380000
# Longitude      -112.325000
# House_price       4.824125
# dtype: float64

# %%
df_cols[(df_cols<=lower)|(df_cols>=upper)].index
# Out:
# RangeIndex(start=0, stop=20640, step=1)

# %%
df_cols
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252        41  6.984127   1.023810         322  2.555556     37.88
# 1      8.3014        21  6.238137   0.971880        2401  2.109842     37.86
# 2      7.2574        52  8.288136   1.073446         496  2.802260     37.85
# 3      5.6431        52  5.817352   1.073059         558  2.547945     37.85
# 4      3.8462        52  6.281853   1.081081         565  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603        25  5.045455   1.133333         845  2.560606     39.48
# 20636  2.5568        18  6.114035   1.315789         356  3.122807     39.49
# 20637  1.7000        17  5.205543   1.120092        1007  2.325635     39.43
# 20638  1.8672        18  5.329513   1.171920         741  2.123209     39.43
# 20639  2.3886        16  5.254717   1.162264        1387  2.616981     39.37
#
#        Longitude  House_price
# ...

# %%
df_cols.corr()
# Out:
#                MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc       1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge    -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms     0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms   -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population   0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup     0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude    -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude   -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
# House_price  0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
#
#              Latitude  Longitude  House_price
# MedInc      -0.079809  -0.015176     0.688075
# HouseAge     0.011173  -0.108197     0.105623
# AveRooms     0.106389  -0.027540     0.151948
# ...

# %%
sea.heatmap(df_cols.corr(),annot=True,cmap='viridis')
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split,cross_val_score
from pandas.core.common import random_state
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
x=df_cols.iloc[:,:-1]
y=df_cols.iloc[:,-1]

# %%
x.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252        41  6.984127   1.023810         322  2.555556     37.88
# 1  8.3014        21  6.238137   0.971880        2401  2.109842     37.86
# 2  7.2574        52  8.288136   1.073446         496  2.802260     37.85
# 3  5.6431        52  5.817352   1.073059         558  2.547945     37.85
# 4  3.8462        52  6.281853   1.081081         565  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
y.head()
# Out:
# 0    4.526
# 1    3.585
# 2    3.521
# 3    3.413
# 4    3.422
# Name: House_price, dtype: float64

# %%
train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.2)

# %%
train_x
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 17221  5.5922        35  6.219373   1.034188         988  2.814815     34.45
# 2449   4.2045        16  7.266129   1.115591        1106  2.973118     36.52
# 14061  3.2708        46  4.323462   1.004556         978  2.227790     32.74
# 6365   4.9968        35  6.156212   1.043050        2112  2.597786     34.17
# 4874   0.9234        40  2.736585   1.385366         662  3.229268     34.02
# ...       ...       ...       ...        ...         ...       ...       ...
# 12910  3.0348        20  5.325475   1.071483        3107  2.362738     38.63
# 17006  5.1701        37  5.598870   1.016949         463  2.615819     37.54
# 8744   4.7062        27  5.869444   1.055556        1109  3.080556     33.81
# 9494   3.1840        23  5.450408   1.064177        2095  2.444574     39.39
# 16733  2.1154         8  4.288660   1.247423         936  9.649485     35.47
#
#        Longitude
# 17221    -119.71
# ...

# %%
train_y
# Out:
# 17221    3.844
# 2449     1.209
# 14061    1.552
# 6365     2.950
# 4874     1.875
#          ...
# 12910    1.505
# 17006    2.942
# 8744     3.570
# 9494     1.405
# 16733    1.172
# Name: House_price, Length: 16512, dtype: float64

# %%
test_y
# Out:
# 18130    3.54400
# 463      2.11300
# 5249     5.00001
# 3021     0.37500
# 6654     1.88600
#           ...
# 2757     0.75500
# 1933     1.72500
# 5630     2.90500
# 1143     0.87500
# 7360     1.42000
# Name: House_price, Length: 4128, dtype: float64

# %%
test_x
# Out:
#        MedInc  HouseAge   AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 18130  4.1473        22   4.826087   1.133433        1479  2.217391     37.35
# 463    2.8846        49   3.857143   1.051429         707  2.020000     37.87
# 5249   7.1576        52  10.344828   1.213793         384  2.648276     34.08
# 3021   3.1250        36   6.444444   1.111111          39  2.166667     35.17
# 6654   2.8631        30   4.427136   1.045226         940  2.361809     34.16
# ...       ...       ...        ...        ...         ...       ...       ...
# 2757   2.1776        35   4.545263   1.035789        1694  3.566316     32.67
# 1933   4.1163         5   5.969854   1.116424        2651  2.755717     38.69
# 5630   5.7764        18   5.770012   1.025090        4336  2.590203     33.76
# 1143   1.6948        15   5.676647   1.221557         893  2.673653     39.83
# 7360   2.0162        28   3.615464   0.998969        3740  3.855670     33.96
#
#        Longitude
# ...

# %%
df.shape
# Out:
# (20640, 9)

# %%
train_x
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 17221  5.5922        35  6.219373   1.034188         988  2.814815     34.45
# 2449   4.2045        16  7.266129   1.115591        1106  2.973118     36.52
# 14061  3.2708        46  4.323462   1.004556         978  2.227790     32.74
# 6365   4.9968        35  6.156212   1.043050        2112  2.597786     34.17
# 4874   0.9234        40  2.736585   1.385366         662  3.229268     34.02
# ...       ...       ...       ...        ...         ...       ...       ...
# 12910  3.0348        20  5.325475   1.071483        3107  2.362738     38.63
# 17006  5.1701        37  5.598870   1.016949         463  2.615819     37.54
# 8744   4.7062        27  5.869444   1.055556        1109  3.080556     33.81
# 9494   3.1840        23  5.450408   1.064177        2095  2.444574     39.39
# 16733  2.1154         8  4.288660   1.247423         936  9.649485     35.47
#
#        Longitude
# 17221    -119.71
# ...

# %%
reg=LinearRegression()

# %%
reg.fit(train_x,train_y)
# Out:
# LinearRegression()

# %%
print(f'co-eff:{reg.coef_}')
print(f'Intercept:{reg.intercept_}')
# Out:
# co-eff:[ 4.31280499e-01  8.93706853e-03 -1.00668513e-01  6.01563346e-01
#  -9.61898542e-06 -3.95971456e-03 -4.27311248e-01 -4.39240837e-01]
# Intercept:-37.24011583103445

# %%
co_eff=reg.coef_
co_eff
# Out:
# array([ 4.31280499e-01,  8.93706853e-03, -1.00668513e-01,  6.01563346e-01,
#        -9.61898542e-06, -3.95971456e-03, -4.27311248e-01, -4.39240837e-01])

# %%
list(zip(train_x.columns,co_eff))
# Out:
# [('MedInc', np.float64(0.4312804989232966)),
#  ('HouseAge', np.float64(0.00893706852801522)),
#  ('AveRooms', np.float64(-0.10066851337243687)),
#  ('AveBedrms', np.float64(0.6015633455742)),
#  ('Population', np.float64(-9.618985420109673e-06)),
#  ('AveOccup', np.float64(-0.003959714564233573)),
#  ('Latitude', np.float64(-0.4273112478545321)),
#  ('Longitude', np.float64(-0.4392408368068713))]

# %%
pred_x=reg.predict(train_x)
pred_y=reg.predict(test_x)

# %%
mse=mean_squared_error(test_y,pred_y)

# %%
mse
# Out:
# 0.5316747297694415

# %%
Rmse=np.sqrt(mean_squared_error(test_y,pred_y))
Rmse
# Out:
# np.float64(0.7291602908616469)

# %%
r2=r2_score(test_y,pred_y)
r2
# Out:
# 0.6094058644169209

# %%
n=len(test_y)
p=test_x.shape[1]
adj_r2=1-((1-r2)*(n-1)/(n-p-1))
adj_r2
# Out:
# 0.6086472450712874

# %%
reg_frm=pd.DataFrame({'Actual':test_y,'Prediction':pred_y,'Diff-per(%)':((test_y-pred_y)/test_y)*100})
reg_frm
# Out:
#         Actual  Prediction  Diff-per(%)
# 18130  3.54400    2.554231    27.928011
# 463    2.11300    2.194981    -3.879849
# 5249   5.00001    3.451450    30.971143
# 3021   0.37500    1.892025  -404.540092
# 6654   1.88600    1.713673     9.137144
# ...        ...         ...          ...
# 2757   0.75500    0.919008   -21.722928
# 1933   1.72500    1.225138    28.977521
# 5630   2.90500    2.931997    -0.929321
# 1143   0.87500    0.117037    86.624381
# 7360   1.42000    1.467792    -3.365619
#
# [4128 rows x 3 columns]

# %%
from sklearn.linear_model import Ridge,Lasso

# %%
ridge=Ridge(alpha=1.0)
ridge.fit(train_x,train_y)
ridge.coef_
# Out:
# array([ 4.31167020e-01,  8.93903393e-03, -1.00450552e-01,  6.00428482e-01,
#        -9.61257738e-06, -3.95929272e-03, -4.27288850e-01, -4.39201976e-01])

# %%
las=Lasso(alpha=1.0)
las.fit(train_x,train_y)
las.coef_
# Out:
# array([ 1.42608845e-01,  5.39821916e-03,  0.00000000e+00,  0.00000000e+00,
#        -1.44531850e-05, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00])

# %%
print(ridge.score(train_x,train_y))
# Out:
# 0.6052665501565309

# %%
plt.Figure(figsize=(100,100))
plt.plot(
    reg_frm['Actual'].values,
    color="#16E677",
    marker='o',
    label='Actual'
)
plt.plot(
    reg_frm['Prediction'].values,
    color='Navy',
    marker='o',
    label='Actual'
)
plt.xlabel('Actual vs Prediction')
plt.ylabel('Price')
plt.legend()
plt.show()
